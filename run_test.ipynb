# %%
import pandas as pd
df_qcm=pd.read_csv('data_csv/all_qcm.csv')
df_qcm.head()
# Out:
#                                                    A  \
# 0                       A. Le traité de Rome de 1957
# 1  A. Une prévention des maladies et affections h...
# 2                        A. La Commission européenne
# 3                           A. Le Parlement européen
# 4           A. La Commission européenne / le Conseil
#
#                                                    B  \
# 0    B. L’Acte Unique européen de Luxembourg de 1986
# 1  B. Un niveau élevé de protection de la santé h...
# 2                                      B. Le Conseil
# 3                             B. Le Conseil européen
# 4     B. Le Conseil européen / le Parlement européen
#
#                                                    C  \
# 0                 C. Le traité de Maastricht de 1992
# 1  C. Une lutte contre les grands fléaux pour la ...
# 2                           C. Le Parlement européen
# 3                                      C. Le Conseil
# ...

# %%
choice = input('Please choose a Chapter : \n Chapter1 : type 1 \n Chapter2 : type 2 \n Chapter3 : type 4 \n Chapter5 : type 5 \n Institutions : type 6  \n Economie : type 7 \n TAPE YOUR CHOICE HERE : ')
# Out:
# Please choose a Chapter :
#  Chapter1 : type 1
#  Chapter2 : type 2
#  Chapter3 : type 4
#  Chapter5 : type 5
#  Institutions : type 6
#  Economie : type 7
#  TAPE YOUR CHOICE HERE :  8
